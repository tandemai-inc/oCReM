# %% [markdown]
# # oCReM Structure Generation Tutorial
#
# This tutorial demonstrates structure generation capabilities of oCReM (optimized Chemical Reassembly), including:
# - Using fragment databases to generate new molecular structures

# %% [markdown]
# ## Mutate molecule <a name='mutate'></a>

# %%
import os
import sys
from rdkit import Chem

sys.path.append(os.path.dirname(os.getcwd())) 

from ta_gen.ocrem.ocrem import mutate_mol
from ta_gen.db import create_db_manager

m = Chem.MolFromSmiles('c1cc(OC)ccc1C')  # toluene
db_manager = create_db_manager('sqlite', db_path='replacements.db')
# db_manager = create_db_manager('postgres', ini_file='replacements.ini')
mols = list(mutate_mol(m, db_manager, max_inc=1))

mols
# Out:
# all tables created successfully (or already exist)
# protected_ids []
# radius 3
# fragments [('C-O-[*:2].C-[*:1]', 'c1cc([*:1])ccc1[*:2]', (0, 1, 2, 5, 6, 7)), ('*1:c:c:c(-[*:1]):c:c:1', 'CO[*:1]', (3, 4)), ('C-[*:1].C-[*:2]', 'c1cc([*:1])ccc1O[*:2]', (0, 1, 2, 3, 5, 6, 7)), ('*:c:c(:c:*)-O-[*:1]', 'C[*:1]', (4,)), ('C-[*:1]', 'COc1ccc([*:1])cc1', (0, 1, 2, 3, 4, 5, 6, 7)), ('*1:c:c:c(-[*:1]):c:c:1', 'C[*:1]', (8,)), ('*1:c:c:c(-[*:2]):c:c:1.C-[*:1]', 'O([*:2])[*:1]', (3,)), ('C-[*:1]', 'Cc1ccc(O[*:1])cc1', (0, 1, 2, 3, 5, 6, 7, 8)), ('C-O-[*:1]', 'Cc1ccc([*:1])cc1', (0, 1, 2, 5, 6, 7, 8))]
# valid fragments: []
# []

# %% [markdown]
# ## Grow molecule <a name='grow'></a>

# %%
import os
import sys
from rdkit import Chem

sys.path.append(os.path.dirname(os.getcwd())) 

from ta_gen.ocrem.ocrem import grow_mol
from ta_gen.db import create_db_manager

m = Chem.MolFromSmiles('c1cc(OC)ccc1C')  # toluene
db_manager = create_db_manager('sqlite', db_path='replacements.db')
# db_manager = create_db_manager('postgres', ini_file='replacements.ini')
mols = list(grow_mol(m, db_manager))

mols
# Out:
# all tables created successfully (or already exist)
# protected_ids []
# radius 3
# fragments [('C-O-[*:2].C-[*:1]', 'c1cc([*:1])ccc1[*:2]', (0, 1, 2, 5, 6, 7)), ('*1:c:c:c(-[*:1]):c:c:1', 'CO[*:1]', (3, 4)), ('C-[*:1].C-[*:2]', 'c1cc([*:1])ccc1O[*:2]', (0, 1, 2, 3, 5, 6, 7)), ('*:c:c(:c:*)-O-[*:1]', 'C[*:1]', (4,)), ('C-[*:1]', 'COc1ccc([*:1])cc1', (0, 1, 2, 3, 4, 5, 6, 7)), ('*1:c:c:c(-[*:1]):c:c:1', 'C[*:1]', (8,)), ('*1:c:c:c(-[*:2]):c:c:1.C-[*:1]', 'O([*:2])[*:1]', (3,)), ('C-[*:1]', 'Cc1ccc(O[*:1])cc1', (0, 1, 2, 3, 5, 6, 7, 8)), ('C-O-[*:1]', 'Cc1ccc([*:1])cc1', (0, 1, 2, 5, 6, 7, 8))]
# valid fragments: []
# []

# %% [markdown]
# ## Link molecule <a name='grow'></a>

# %%
import os
import sys
from rdkit import Chem

sys.path.append(os.path.dirname(os.getcwd())) 

from ta_gen.ocrem.ocrem import link_mol
from ta_gen.db import create_db_manager

m1 = Chem.MolFromSmiles('c1cc(OC)ccc1C')  # toluene
m2 = Chem.MolFromSmiles('NCC(=O)O')  # glycine
db_manager = create_db_manager('sqlite', db_path='replacements.db')
# db_manager = create_db_manager('postgres', ini_file='replacements.ini')
mols = list(link_mol(m1, m2, db_manager))

mols
# Out:
# all tables created successfully (or already exist)
# fragments []
# []
